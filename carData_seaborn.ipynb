# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
car_datasheet = pd.read_csv("cars_ds_final.csv")

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0    Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1    Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2    Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3    Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4    Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
# 5           5    Tata  Nano Genx      Xma      Rs. 3,14,815       624 cc
# 6           6  Datsun    Redi-Go        D      Rs. 2,79,650       799 cc
# 7           7  Datsun    Redi-Go        T      Rs. 3,51,832       799 cc
# 8           8  Datsun    Redi-Go        A      Rs. 3,33,419       799 cc
# 9           9  Datsun    Redi-Go        S      Rs. 3,62,000       799 cc
#
#    Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0        2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
car_datasheet.drop(["Leather_Wrapped_Steering" , "Automatic_Headlamps" , "Engine_Type" ,"ASR_/_Traction_Control" ,"Cruise_Control", "USB_Ports"] ,  axis = 1, inplace = True)

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0    Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1    Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2    Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3    Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4    Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
# 5           5    Tata  Nano Genx      Xma      Rs. 3,14,815       624 cc
# 6           6  Datsun    Redi-Go        D      Rs. 2,79,650       799 cc
# 7           7  Datsun    Redi-Go        T      Rs. 3,51,832       799 cc
# 8           8  Datsun    Redi-Go        A      Rs. 3,33,419       799 cc
# 9           9  Datsun    Redi-Go        S      Rs. 3,62,000       799 cc
#
#    Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0        2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
car_datasheet.drop([ "Average_Speed" , "EBA_(Electronic_Brake_Assist)" , "Seat_Height_Adjustment" , "Navigation_System" , "Second_Row_AC_Vents" , "Tyre_Pressure_Monitoring_System",  "Rear_Center_Armrest" , "iPod_Compatibility" , "ESP_(Electronic_Stability_Program)" , "Cooled_Glove_Box"] , axis = 1 , inplace = True)

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0    Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1    Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2    Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3    Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4    Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
# 5           5    Tata  Nano Genx      Xma      Rs. 3,14,815       624 cc
# 6           6  Datsun    Redi-Go        D      Rs. 2,79,650       799 cc
# 7           7  Datsun    Redi-Go        T      Rs. 3,51,832       799 cc
# 8           8  Datsun    Redi-Go        A      Rs. 3,33,419       799 cc
# 9           9  Datsun    Redi-Go        S      Rs. 3,62,000       799 cc
#
#    Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0        2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
car_datasheet.drop(["Other_Specs" , "Other_specs" , "Parking_Assistance" , "Key_Off_Reminder" , "USB_Compatibility" , "Android_Auto" , "Apple_CarPlay" , "Cigarette_Lighter" , "Infotainment_Screen" , "Multifunction_Steering_Wheel" ] , axis = 1 , inplace = True)

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0    Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1    Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2    Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3    Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4    Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
# 5           5    Tata  Nano Genx      Xma      Rs. 3,14,815       624 cc
# 6           6  Datsun    Redi-Go        D      Rs. 2,79,650       799 cc
# 7           7  Datsun    Redi-Go        T      Rs. 3,51,832       799 cc
# 8           8  Datsun    Redi-Go        A      Rs. 3,33,419       799 cc
# 9           9  Datsun    Redi-Go        S      Rs. 3,62,000       799 cc
#
#    Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 0        2.0                  2.0   RWD (Rear Wheel Drive)
# ...

# %%
car_datasheet.drop(["Ex-Showroom_Price"] ,axis = 1 , inplace = True)

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Displacement  Cylinders  \
# 0           0    Tata  Nano Genx       Xt       624 cc        2.0
# 1           1    Tata  Nano Genx       Xe       624 cc        2.0
# 2           2    Tata  Nano Genx  Emax Xm       624 cc        2.0
# 3           3    Tata  Nano Genx      Xta       624 cc        2.0
# 4           4    Tata  Nano Genx       Xm       624 cc        2.0
# 5           5    Tata  Nano Genx      Xma       624 cc        2.0
# 6           6  Datsun    Redi-Go        D       799 cc        3.0
# 7           7  Datsun    Redi-Go        T       799 cc        3.0
# 8           8  Datsun    Redi-Go        A       799 cc        3.0
# 9           9  Datsun    Redi-Go        S       799 cc        3.0
#
#    Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# 0                  2.0   RWD (Rear Wheel Drive)                In-line
# 1                  2.0   RWD (Rear Wheel Drive)                In-line
# ...

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Displacement  Cylinders  \
# 0           0    Tata  Nano Genx       Xt       624 cc        2.0
# 1           1    Tata  Nano Genx       Xe       624 cc        2.0
# 2           2    Tata  Nano Genx  Emax Xm       624 cc        2.0
# 3           3    Tata  Nano Genx      Xta       624 cc        2.0
# 4           4    Tata  Nano Genx       Xm       624 cc        2.0
# 5           5    Tata  Nano Genx      Xma       624 cc        2.0
# 6           6  Datsun    Redi-Go        D       799 cc        3.0
# 7           7  Datsun    Redi-Go        T       799 cc        3.0
# 8           8  Datsun    Redi-Go        A       799 cc        3.0
# 9           9  Datsun    Redi-Go        S       799 cc        3.0
#
#    Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# 0                  2.0   RWD (Rear Wheel Drive)                In-line
# 1                  2.0   RWD (Rear Wheel Drive)                In-line
# ...

# %%
car_datasheet.drop(["Drivetrain" , "Cylinder_Configuration" , "Emission_Norm"] , axis =1 , inplace = True)

# %%
car_datasheet.head(10)
# Out:
#    Unnamed: 0    Make      Model  Variant Displacement  Cylinders  \
# 0           0    Tata  Nano Genx       Xt       624 cc        2.0
# 1           1    Tata  Nano Genx       Xe       624 cc        2.0
# 2           2    Tata  Nano Genx  Emax Xm       624 cc        2.0
# 3           3    Tata  Nano Genx      Xta       624 cc        2.0
# 4           4    Tata  Nano Genx       Xm       624 cc        2.0
# 5           5    Tata  Nano Genx      Xma       624 cc        2.0
# 6           6  Datsun    Redi-Go        D       799 cc        3.0
# 7           7  Datsun    Redi-Go        T       799 cc        3.0
# 8           8  Datsun    Redi-Go        A       799 cc        3.0
# 9           9  Datsun    Redi-Go        S       799 cc        3.0
#
#    Valves_Per_Cylinder    Engine_Location Fuel_System Fuel_Tank_Capacity  ...  \
# 0                  2.0   Rear, Transverse   Injection          24 litres  ...
# 1                  2.0   Rear, Transverse   Injection          24 litres  ...
# ...

# %%
#barplot
res = sns.barplot(car_datasheet[  'Cylinders'   ] )
plt.show()

# %%
sns.barplot(x=car_datasheet.Cylinders , y=car_datasheet.Valves_Per_Cylinder  )
plt.show()

# %%
print(car_datasheet)
# Out:
#       Unnamed: 0        Make      Model        Variant Displacement  \
# 0              0        Tata  Nano Genx             Xt       624 cc
# 1              1        Tata  Nano Genx             Xe       624 cc
# 2              2        Tata  Nano Genx        Emax Xm       624 cc
# 3              3        Tata  Nano Genx            Xta       624 cc
# 4              4        Tata  Nano Genx             Xm       624 cc
# ...          ...         ...        ...            ...          ...
# 1271        1271       Honda       City   Vx Mt Diesel      1498 cc
# 1272        1272       Honda       City   Zx Mt Diesel      1498 cc
# 1273        1273       Honda       City  Zx Cvt Petrol      1497 cc
# 1274        1274       Honda       City   V Cvt Petrol      1497 cc
# 1275        1275  Mitsubishi    Montero         3.2 At      3200 cc
#
#       Cylinders  Valves_Per_Cylinder      Engine_Location Fuel_System  \
# 0           2.0                  2.0     Rear, Transverse   Injection
# ...

# %%
car_datasheet.head(30)
# Out:
#     Unnamed: 0           Make      Model                Variant Displacement  \
# 0            0           Tata  Nano Genx                     Xt       624 cc
# 1            1           Tata  Nano Genx                     Xe       624 cc
# 2            2           Tata  Nano Genx                Emax Xm       624 cc
# 3            3           Tata  Nano Genx                    Xta       624 cc
# 4            4           Tata  Nano Genx                     Xm       624 cc
# 5            5           Tata  Nano Genx                    Xma       624 cc
# 6            6         Datsun    Redi-Go                      D       799 cc
# 7            7         Datsun    Redi-Go                      T       799 cc
# 8            8         Datsun    Redi-Go                      A       799 cc
# 9            9         Datsun    Redi-Go                      S       799 cc
# 10          10         Datsun    Redi-Go                  1.0 S       999 cc
# ...

# %%
res = sns.barplot(x='Cylinders' , y = 'Valves_Per_Cylinder' , data = car_datasheet)
plt.show()

# %%
res = sns.barplot(x='Cylinders' , y = 'Valves_Per_Cylinder' , data = car_datasheet , color = 'black')

# %%
#Countplot 

res = sns.countplot(x = 'Cylinders' , data =  car_datasheet, palette = "Set1")
plt.show()

# %%
res = sns.countplot(x = "Cylinders" , data = car_datasheet  , color = "Black" )
plt.show()

# %%
sns.countplot(y = "Cylinders" , data = car_datasheet , color = 'black')
# Out:
# <Axes: xlabel='count', ylabel='Cylinders'>

# %%
#heatmap 
correlation_matrix = car_datasheet.corr()
sns.heatmap(correlation_matrix , cbar= True , linewidths = 0.5)
plt.show()
# Out:
# C:\Users\annu\AppData\Local\Temp\ipykernel_2580\2164932016.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = car_datasheet.corr()

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.scatterplot(x = 'sepal_length' , y = 'petal_length' , data = iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = 'sepal_length' , y = 'petal_length' , data = iris , hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = 'sepal_length' , y = 'petal_length' , data = iris , hue = 'species' , size = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(iris , hue = 'species' , palette = 'Set1')

# %%
#Lmplot 
sns.lmplot( x = 'petal_length' , y = 'petal_width' , data = iris)

# %%
sns.lmplot( x = 'petal_length' , y = 'petal_width' , data = iris , markers = ["o" , "*" , "." ] , hue = 'species')

# %%
#Boxplot
sns.boxplot(x = 'species' , y = 'sepal_width' , data = iris)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>
